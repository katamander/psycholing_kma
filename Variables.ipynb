# %% [markdown]
# # Variables and variable types
#
# ## "Regular" variables
#
# 1. strings
# 1. integers
# 1. floats
#
# ## "Collection" variables
#
# 1. tuples
# 1. lists
# 1. sets
# 1. dictionaries
#
# From https://www.w3schools.com:
#
# - **Strings** are for storing text
# - **Integers** are for storing whole numbers, positive or negative (such as 123 or -456), without decimals.
# - **Floats** are for storing positive and negative numbers with a decimal point, like 35.3, or -2.34
# - **Lists** are collections which are ordered and changeable. Allows duplicate members.
# - **Tuples** are collections which are ordered and unchangeable. Allows duplicate members.
# - **Sets** are collections which are unordered, "unchangeable", and unindexed. No duplicate members.
# - **Dictionaries** are collections which are ordered and changeable. No duplicate members.

# %% [markdown]
# ## Strings

# %%
fruit = "strawberry"

# %% [markdown]
# ## Integers

# %%
amount = 20

# %% [markdown]
# ## Floats

# %%
price = 25.95

# %% [markdown]
# ## Lists

# %%
fruit_list = ["strawberry", "mango", "orange", "mango", "plum"]
fruit_list[2]
# Out:
# 'orange'

# %% [markdown]
# ## Tuples

# %%
fruit_tuple = tuple(fruit_list)
fruit_tuple
other_tuple = ("a", "b", "c", "d", 19, 3, "3")
other_tuple
# Out:
# ('a', 'b', 'c', 'd', 19, 3, '3')

# %% [markdown]
# ## Sets

# %%
fruit_set = set(fruit_list)
fruit_set
other_set = {"a", "b", "c", "d", 19, 3, "3"}
other_set
# Out:
# {19, 3, '3', 'a', 'b', 'c', 'd'}

# %% [markdown]
# ## Dictionaries

# %%
fruit_dictionary = {"fruit": "strawberry",
                    "amount": 20,
                    "price": price,
                    "taste": "great"}
fruit_dictionary["price"]
#dictionaries of lists are also possible, e.g. "fruit": fruit_list,
# Out:
# 25.95
