# %% [markdown]
# # my first notebook
#
# In this notebook, I will learn about the basic variables in python. They are:
# 1. strings
# 2. integers
# 3. floats
#
# _Let's go!_

# %% [markdown]
# ## Strings

# %%
fruit = "grapes"
fruit.replace('a','@')
# Out:
# 'gr@pes'

# %% [markdown]
# ## Integers

# %%
chips = 2
cookies = 3
snacks = chips + cookies
print(chips, cookies, snacks)
# Out:
# 2 3 5

# %%
type(snacks)
# Out:
# int

# %%
dir(snacks)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %% [markdown]
# ## Floats

# %%
cookies = 3.2

# %%
type(cookies)
# Out:
# float
